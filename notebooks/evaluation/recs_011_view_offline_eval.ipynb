# %% [markdown]
# # View offline eval results (read-only)
#
# Loads CSVs written by `recs_job_eval_offline.py`. **Does not re-score** examples or run the A–F fusion grid.
#
# Prerequisite: `python scripts/recs_job_eval_offline.py configs/recs_job_eval_offline.json` (optionally with `--examples-parquet`).
#
# Contract notes: [`docs/recommendation_evaluation_overview.md`](../../docs/recommendation_evaluation_overview.md)

# %%
from __future__ import annotations

import json
from pathlib import Path

import pandas as pd
from IPython.display import display

# --- pick run folder ---
# "latest"  -> artifacts/recs/offline_eval/runs/latest
# or a named archive, e.g. "20260526_144828__baseline_retrieval"
EVAL_RUN = "latest"

REPO_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / "pyproject.toml").is_file())
RUNS_ROOT = REPO_ROOT / "artifacts/recs/offline_eval/runs"
EVAL_DIR = RUNS_ROOT / "latest" if EVAL_RUN == "latest" else RUNS_ROOT / EVAL_RUN

if not EVAL_DIR.is_dir():
    raise FileNotFoundError(f"Eval run dir not found: {EVAL_DIR}")

PATHS = {
    "ranking_overall": EVAL_DIR / "eval_ranking_overall.csv",
    "ranking_by_slice": EVAL_DIR / "eval_ranking_by_slice.csv",
    "retrieval_overall": EVAL_DIR / "eval_retrieval_overall.csv",
    "retrieval_by_slice": EVAL_DIR / "eval_retrieval_by_slice.csv",
    "run_meta": EVAL_DIR / "eval_offline_run_meta.json",
}
print(f"EVAL_DIR={EVAL_DIR}")
# Out:
# EVAL_DIR=/home/ryanr/workspace/steam_recommendations/artifacts/recs/offline_eval/runs/latest

# %%
def _load_csv(key: str) -> pd.DataFrame | None:
    path = PATHS[key]
    if not path.is_file():
        print(f"skip {key}: missing {path.name}")
        return None
    return pd.read_csv(path)

rank_overall = _load_csv("ranking_overall")
rank_slice = _load_csv("ranking_by_slice")
retr_overall = _load_csv("retrieval_overall")
retr_slice = _load_csv("retrieval_by_slice")

run_meta = None
if PATHS["run_meta"].is_file():
    run_meta = json.loads(PATHS["run_meta"].read_text(encoding="utf-8"))
    print("methods:", run_meta.get("methods_requested"))
    print(
        "k:",
        f"k_final={run_meta.get('k_final')}",
        f"k_retrieval={run_meta.get('k_retrieval')}",
    )
else:
    print("no eval_offline_run_meta.json")
# Out:
# methods: ['raw', 'popularity_train', 'multi_mean_train', 'fusion_c_raw_plus_behavior', 'two_tower_v1', 'two_tower_v1_v2a_embed_query_logpop_blend', 'two_tower_v1_heuristic_logpop_blend', 'rag_chunk_v1_raw_query', 'rag_chunk_v1_query_plus_desc', 'rag_chunk_v1_vector_blend_query', 'rag_chunk_v1_vector_blend_query_v2a_embed_query_logpop_blend']
# k: k_final=10 k_retrieval=100

# %%
if rank_overall is not None:
    sort_cols = [c for c in ["NDCG@K", "MAP@K", "MRR", "Hit@K"] if c in rank_overall.columns]
    display(rank_overall.sort_values(sort_cols, ascending=False))

if retr_overall is not None:
    sort_cols = [c for c in ["Recall@K", "Precision@K", "Hit@K"] if c in retr_overall.columns]
    display(retr_overall.sort_values(sort_cols, ascending=False))
# Out:
#                                                method    Hit@K  Precision@K  \
# 0           two_tower_v1_v2a_embed_query_logpop_blend  0.19584     0.019816
# 1                 two_tower_v1_heuristic_logpop_blend  0.19328     0.019560
# 2   rag_chunk_v1_vector_blend_query_v2a_embed_quer...  0.18144     0.018336
# 3                                    popularity_train  0.15112     0.015184
# 4                     rag_chunk_v1_vector_blend_query  0.10200     0.010280
# 5                        rag_chunk_v1_query_plus_desc  0.10152     0.010240
# 6                          fusion_c_raw_plus_behavior  0.08536     0.008640
# 7                                    multi_mean_train  0.08328     0.008376
# 8                              rag_chunk_v1_raw_query  0.07656     0.007728
# 9                                                 raw  0.07168     0.007216
# 10                                       two_tower_v1  0.04680     0.004728
#
#     Recall@K     MAP@K    NDCG@K       MRR  OracleHit@K  OracleNDCG@K  \
# 0   0.186324  0.066797  0.095345  0.069567      0.51224      0.498310
# 1   0.184095  0.064321  0.092892  0.067059      0.51224      0.498310
# 2   0.173688  0.062113  0.088675  0.064518      0.53168      0.518090
# 3   0.146796  0.050594  0.073109  0.052221      0.76280      0.752102
# 4   0.095435  0.035890  0.050307  0.038319      0.53168      0.518090
# 5   0.095154  0.034710  0.049339  0.037027      0.51512      0.501217
# 6   0.079430  0.025877  0.038836  0.027940      0.50632      0.492244
# 7   0.076479  0.025349  0.037700  0.027358      0.48592      0.471551
# 8   0.071635  0.025110  0.036303  0.026664      0.48608      0.472837
# 9   0.066606  0.024917  0.035020  0.026749      0.45296      0.438800
# 10  0.043740  0.010325  0.018161  0.011008      0.51224      0.498310
#
#       ILD@10  CatalogCoverage@10  Novelty@10  \
# 0   0.202787            0.511111    6.296105
# 1   0.204632            0.501587    6.272161
# 2   0.208377            0.444444    6.192206
# 3   0.212335            0.034921    5.317471
# 4   0.171750            1.000000    9.079760
# 5   0.168942            1.000000    9.306055
# 6   0.134907            1.000000    9.653051
# 7   0.146727            1.000000    9.798976
# 8   0.174608            1.000000    9.412037
# 9   0.160723            1.000000    9.838045
# 10  0.261639            0.987302   12.167556
#
#     PersonalizationGapVsPopularity@10                 retrieval_method
# 0                            0.726256                     two_tower_v1
# 1                            0.720097                     two_tower_v1
# 2                            0.782842  rag_chunk_v1_vector_blend_query
# 3                            0.000000                 popularity_train
# 4                            0.983432  rag_chunk_v1_vector_blend_query
# 5                            0.984923     rag_chunk_v1_query_plus_desc
# 6                            0.974458       fusion_c_raw_plus_behavior
# 7                            0.976841                 multi_mean_train
# 8                            0.985324           rag_chunk_v1_raw_query
# 9                            0.979470                              raw
# 10                           0.995623                     two_tower_v1
#                             method    Hit@K  Precision@K  Recall@K
# 0                 popularity_train  0.76280     0.008161  0.748578
# 1  rag_chunk_v1_vector_blend_query  0.53168     0.005666  0.513878
# 2     rag_chunk_v1_query_plus_desc  0.51512     0.005474  0.496925
# 3                     two_tower_v1  0.51224     0.005414  0.494053
# 4       fusion_c_raw_plus_behavior  0.50632     0.005362  0.487961
# 5           rag_chunk_v1_raw_query  0.48608     0.005142  0.468807
# 6                 multi_mean_train  0.48592     0.005159  0.467191
# 7                              raw  0.45296     0.004801  0.434516

# %%
if retr_slice is not None:
    print("Retrieval Slice:")
    display(retr_slice.sort_values(["slice_name", "Recall@K"], ascending=[True, False]))

if rank_slice is not None:
    print("Ranking Slice:")
    display(rank_slice.sort_values(["slice_name", "NDCG@K"], ascending=[True, False]))
# Out:
# Retrieval Slice:
#                slice_name                           method     Hit@K  \
# 0    slice_a_multi_target                 popularity_train  0.892414
# 1    slice_a_multi_target  rag_chunk_v1_vector_blend_query  0.823448
# 2    slice_a_multi_target     rag_chunk_v1_query_plus_desc  0.798621
# 3    slice_a_multi_target                 multi_mean_train  0.794483
# 4    slice_a_multi_target       fusion_c_raw_plus_behavior  0.777931
# 5    slice_a_multi_target                     two_tower_v1  0.773793
# 6    slice_a_multi_target           rag_chunk_v1_raw_query  0.737931
# 7    slice_a_multi_target                              raw  0.747586
# 8   slice_b_single_target                 popularity_train  0.754820
# 9   slice_b_single_target  rag_chunk_v1_vector_blend_query  0.513715
# 10  slice_b_single_target     rag_chunk_v1_query_plus_desc  0.497665
# 11  slice_b_single_target                     two_tower_v1  0.496136
# 12  slice_b_single_target       fusion_c_raw_plus_behavior  0.489597
# 13  slice_b_single_target           rag_chunk_v1_raw_query  0.470573
# 14  slice_b_single_target                 multi_mean_train  0.466921
# 15  slice_b_single_target                              raw  0.434820
#
#     Precision@K  Recall@K
# 0      0.018110  0.647212
# 1      0.014262  0.516522
# 2      0.013559  0.484910
# 3      0.013117  0.471565
# 4      0.012924  0.461392
# 5      0.012772  0.460228
# 6      0.012234  0.440120
# 7      0.012152  0.429578
# 8      0.007548  0.754820
# 9      0.005137  0.513715
# 10     0.004977  0.497665
# 11     0.004961  0.496136
# 12     0.004896  0.489597
# 13     0.004706  0.470573
# 14     0.004669  0.466921
# 15     0.004348  0.434820
# Ranking Slice:
#                slice_name                                             method  \
# 0    slice_a_multi_target          two_tower_v1_v2a_embed_query_logpop_blend
# 1    slice_a_multi_target                two_tower_v1_heuristic_logpop_blend
# 2    slice_a_multi_target  rag_chunk_v1_vector_blend_query_v2a_embed_quer...
# 3    slice_a_multi_target                    rag_chunk_v1_vector_blend_query
# 4    slice_a_multi_target                       rag_chunk_v1_query_plus_desc
# 5    slice_a_multi_target                         fusion_c_raw_plus_behavior
# 6    slice_a_multi_target                                   multi_mean_train
# 7    slice_a_multi_target                                                raw
# 8    slice_a_multi_target                             rag_chunk_v1_raw_query
# 9    slice_a_multi_target                                   popularity_train
# 10   slice_a_multi_target                                       two_tower_v1
# 11  slice_b_single_target          two_tower_v1_v2a_embed_query_logpop_blend
# 12  slice_b_single_target                two_tower_v1_heuristic_logpop_blend
# 13  slice_b_single_target  rag_chunk_v1_vector_blend_query_v2a_embed_quer...
# 14  slice_b_single_target                                   popularity_train
# 15  slice_b_single_target                    rag_chunk_v1_vector_blend_query
# 16  slice_b_single_target                       rag_chunk_v1_query_plus_desc
# 17  slice_b_single_target                         fusion_c_raw_plus_behavior
# 18  slice_b_single_target                                   multi_mean_train
# 19  slice_b_single_target                             rag_chunk_v1_raw_query
# 20  slice_b_single_target                                                raw
# 21  slice_b_single_target                                       two_tower_v1
#
#        Hit@K  Precision@K  Recall@K     MAP@K    NDCG@K       MRR  \
# 0   0.281379     0.032138  0.117319  0.035030  0.070334  0.082787
# 1   0.271724     0.031172  0.113367  0.034181  0.068322  0.081396
# 2   0.231724     0.026483  0.098068  0.031696  0.060467  0.073175
# 3   0.191724     0.020552  0.078537  0.028929  0.052658  0.070813
# 4   0.184828     0.020000  0.075068  0.027721  0.050566  0.067662
# 5   0.172414     0.019034  0.070175  0.025696  0.046757  0.061264
# 6   0.188966     0.019724  0.071700  0.021733  0.044159  0.056376
# 7   0.143448     0.015172  0.055964  0.021677  0.038812  0.053255
# 8   0.146207     0.015862  0.061290  0.019391  0.037628  0.046195
# 9   0.128276     0.014069  0.053728  0.019418  0.035444  0.047469
# 10  0.091034     0.009931  0.038280  0.009408  0.020537  0.021192
# 11  0.190573     0.019057  0.190573  0.068753  0.096885  0.068753
# 12  0.188450     0.018845  0.188450  0.066176  0.094404  0.066176
# 13  0.178344     0.017834  0.178344  0.063985  0.090412  0.063985
# 14  0.152527     0.015253  0.152527  0.052514  0.075428  0.052514
# 15  0.096476     0.009648  0.096476  0.036319  0.050162  0.036319
# 16  0.096391     0.009639  0.096391  0.035141  0.049263  0.035141
# 17  0.080000     0.008000  0.080000  0.025888  0.038348  0.025888
# 18  0.076773     0.007677  0.076773  0.025572  0.037302  0.025572
# 19  0.072272     0.007227  0.072272  0.025462  0.036221  0.025462
# 20  0.067261     0.006726  0.067261  0.025117  0.034786  0.025117
# 21  0.044076     0.004408  0.044076  0.010381  0.018015  0.010381
#
#     OracleHit@K  OracleNDCG@K    ILD@10  CatalogCoverage@10  Novelty@10  \
# 0      0.773793      0.533618  0.201265            0.434921    6.534829
# 1      0.773793      0.533618  0.203806            0.412698    6.504750
# 2      0.823448      0.589142  0.207860            0.349206    6.234571
# 3      0.823448      0.589142  0.175855            0.946032    9.096803
# 4      0.798621      0.558915  0.171459            0.952381    9.351036
# 5      0.777931      0.535239  0.122921            0.892063    9.840357
# 6      0.794483      0.546735  0.137577            0.955556    9.940777
# 7      0.747586      0.503441  0.161907            0.996825    9.955937
# 8      0.737931      0.509606  0.176664            0.984127    9.517988
# 9      0.892414      0.707962  0.212240            0.034921    5.312688
# 10     0.773793      0.533618  0.256915            0.933333   12.163190
# 11     0.496136      0.496136  0.202881            0.504762    6.281407
# 12     0.496136      0.496136  0.204683            0.501587    6.257840
# 13     0.513715      0.513715  0.208409            0.444444    6.189598
# 14     0.754820      0.754820  0.212341            0.034921    5.317765
# 15     0.513715      0.513715  0.171497            1.000000    9.078711
# 16     0.497665      0.497665  0.168787            1.000000    9.303286
# 17     0.489597      0.489597  0.135645            1.000000    9.641518
# 18     0.466921      0.466921  0.147290            1.000000    9.790245
# 19     0.470573      0.470573  0.174481            1.000000    9.405513
# 20     0.434820      0.434820  0.160650            1.000000    9.830787
# 21     0.496136      0.496136  0.261930            0.987302   12.167824
#
#     PersonalizationGapVsPopularity@10                 retrieval_method
# 0                            0.798229                     two_tower_v1
# 1                            0.793487                     two_tower_v1
# 2                            0.800892  rag_chunk_v1_vector_blend_query
# 3                            0.986180  rag_chunk_v1_vector_blend_query
# 4                            0.987796     rag_chunk_v1_query_plus_desc
# 5                            0.986083       fusion_c_raw_plus_behavior
# 6                            0.982319                 multi_mean_train
# 7                            0.983968                              raw
# 8                            0.987783           rag_chunk_v1_raw_query
# 9                            0.000000                 popularity_train
# 10                           0.997354                     two_tower_v1
# 11                           0.721825                     two_tower_v1
# 12                           0.715579                     two_tower_v1
# 13                           0.781731  rag_chunk_v1_vector_blend_query
# 14                           0.000000                 popularity_train
# 15                           0.983263  rag_chunk_v1_vector_blend_query
# 16                           0.984746     rag_chunk_v1_query_plus_desc
# 17                           0.973742       fusion_c_raw_plus_behavior
# 18                           0.976504                 multi_mean_train
# 19                           0.985173           rag_chunk_v1_raw_query
# 20                           0.979193                              raw
# 21                           0.995516                     two_tower_v1

# %%
try:
    import matplotlib.pyplot as plt
except ImportError:
    plt = None

if plt is not None and rank_overall is not None and "NDCG@K" in rank_overall.columns:
    df = rank_overall.sort_values("NDCG@K", ascending=True)
    fig, ax = plt.subplots(figsize=(8, max(3, 0.4 * len(df))))
    ax.barh(df["method"], df["NDCG@K"])
    ax.set_xlabel("NDCG@K (ranking contract)")
    ax.set_title(f"Ranking overall — {EVAL_RUN}")
    plt.tight_layout()
    plt.show()
else:
    print("matplotlib not available or ranking table missing; tables above are enough.")

# %%
from __future__ import annotations

import json
from pathlib import Path

import pandas as pd
from IPython.display import display

# --- pick run folder ---
# "latest"  -> artifacts/recs/offline_eval/runs/latest
# or a named archive, e.g. "20260526_144828__baseline_retrieval"
EVAL_RUN = "latest"

REPO_ROOT = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / "pyproject.toml").is_file())
RUNS_ROOT = REPO_ROOT / "artifacts/recs/offline_eval/runs"
EVAL_DIR = RUNS_ROOT / "latest" if EVAL_RUN == "latest" else RUNS_ROOT / EVAL_RUN

if not EVAL_DIR.is_dir():
    raise FileNotFoundError(f"Eval run dir not found: {EVAL_DIR}")

PATHS = {
    "ranking_overall": EVAL_DIR / "eval_ranking_overall.csv",
    "ranking_by_slice": EVAL_DIR / "eval_ranking_by_slice.csv",
    "retrieval_overall": EVAL_DIR / "eval_retrieval_overall.csv",
    "retrieval_by_slice": EVAL_DIR / "eval_retrieval_by_slice.csv",
    "run_meta": EVAL_DIR / "eval_offline_run_meta.json",
}
print(f"EVAL_DIR={EVAL_DIR}")
# Out:
# EVAL_DIR=/home/ryanr/workspace/steam_recommendations/artifacts/recs/offline_eval/runs/latest

# %%
def _load_csv(key: str) -> pd.DataFrame | None:
    path = PATHS[key]
    if not path.is_file():
        print(f"skip {key}: missing {path.name}")
        return None
    return pd.read_csv(path)

rank_overall = _load_csv("ranking_overall")
rank_slice = _load_csv("ranking_by_slice")
retr_overall = _load_csv("retrieval_overall")
retr_slice = _load_csv("retrieval_by_slice")

run_meta = None
if PATHS["run_meta"].is_file():
    run_meta = json.loads(PATHS["run_meta"].read_text(encoding="utf-8"))
    print("methods:", run_meta.get("methods_requested"))
    print(
        "k:",
        f"k_final={run_meta.get('k_final')}",
        f"k_retrieval={run_meta.get('k_retrieval')}",
    )
else:
    print("no eval_offline_run_meta.json")
# Out:
# methods: ['raw', 'popularity_train', 'multi_mean_train', 'fusion_c_raw_plus_behavior', 'two_tower_v1', 'two_tower_v1_v2a_embed_query_logpop_blend', 'two_tower_v1_heuristic_logpop_blend', 'rag_chunk_v1_raw_query', 'rag_chunk_v1_query_plus_desc', 'rag_chunk_v1_vector_blend_query', 'rag_chunk_v1_vector_blend_query_v2a_embed_query_logpop_blend']
# k: k_final=10 k_retrieval=100

# %%
if rank_overall is not None:
    sort_cols = [c for c in ["NDCG@K", "MAP@K", "MRR", "Hit@K"] if c in rank_overall.columns]
    display(rank_overall.sort_values(sort_cols, ascending=False))

if retr_overall is not None:
    sort_cols = [c for c in ["Recall@K", "Precision@K", "Hit@K"] if c in retr_overall.columns]
    display(retr_overall.sort_values(sort_cols, ascending=False))
# Out:
#                                                method    Hit@K  Precision@K  \
# 0           two_tower_v1_v2a_embed_query_logpop_blend  0.19584     0.019816
# 1                 two_tower_v1_heuristic_logpop_blend  0.19328     0.019560
# 2   rag_chunk_v1_vector_blend_query_v2a_embed_quer...  0.18144     0.018336
# 3                                    popularity_train  0.15112     0.015184
# 4                     rag_chunk_v1_vector_blend_query  0.10200     0.010280
# 5                        rag_chunk_v1_query_plus_desc  0.10152     0.010240
# 6                          fusion_c_raw_plus_behavior  0.08536     0.008640
# 7                                    multi_mean_train  0.08328     0.008376
# 8                              rag_chunk_v1_raw_query  0.07656     0.007728
# 9                                                 raw  0.07168     0.007216
# 10                                       two_tower_v1  0.04680     0.004728
#
#     Recall@K     MAP@K    NDCG@K       MRR  OracleHit@K  OracleNDCG@K  \
# 0   0.186324  0.066797  0.095345  0.069567      0.51224      0.498310
# 1   0.184095  0.064321  0.092892  0.067059      0.51224      0.498310
# 2   0.173688  0.062113  0.088675  0.064518      0.53168      0.518090
# 3   0.146796  0.050594  0.073109  0.052221      0.76280      0.752102
# 4   0.095435  0.035890  0.050307  0.038319      0.53168      0.518090
# 5   0.095154  0.034710  0.049339  0.037027      0.51512      0.501217
# 6   0.079430  0.025877  0.038836  0.027940      0.50632      0.492244
# 7   0.076479  0.025349  0.037700  0.027358      0.48592      0.471551
# 8   0.071635  0.025110  0.036303  0.026664      0.48608      0.472837
# 9   0.066606  0.024917  0.035020  0.026749      0.45296      0.438800
# 10  0.043740  0.010325  0.018161  0.011008      0.51224      0.498310
#
#       ILD@10  CatalogCoverage@10  Novelty@10  \
# 0   0.202787            0.511111    6.296105
# 1   0.204632            0.501587    6.272161
# 2   0.208377            0.444444    6.192206
# 3   0.212335            0.034921    5.317471
# 4   0.171750            1.000000    9.079760
# 5   0.168942            1.000000    9.306055
# 6   0.134907            1.000000    9.653051
# 7   0.146727            1.000000    9.798976
# 8   0.174608            1.000000    9.412037
# 9   0.160723            1.000000    9.838045
# 10  0.261639            0.987302   12.167556
#
#     PersonalizationGapVsPopularity@10                 retrieval_method
# 0                            0.726256                     two_tower_v1
# 1                            0.720097                     two_tower_v1
# 2                            0.782842  rag_chunk_v1_vector_blend_query
# 3                            0.000000                 popularity_train
# 4                            0.983432  rag_chunk_v1_vector_blend_query
# 5                            0.984923     rag_chunk_v1_query_plus_desc
# 6                            0.974458       fusion_c_raw_plus_behavior
# 7                            0.976841                 multi_mean_train
# 8                            0.985324           rag_chunk_v1_raw_query
# 9                            0.979470                              raw
# 10                           0.995623                     two_tower_v1
#                             method    Hit@K  Precision@K  Recall@K
# 0                 popularity_train  0.76280     0.008161  0.748578
# 1  rag_chunk_v1_vector_blend_query  0.53168     0.005666  0.513878
# 2     rag_chunk_v1_query_plus_desc  0.51512     0.005474  0.496925
# 3                     two_tower_v1  0.51224     0.005414  0.494053
# 4       fusion_c_raw_plus_behavior  0.50632     0.005362  0.487961
# 5           rag_chunk_v1_raw_query  0.48608     0.005142  0.468807
# 6                 multi_mean_train  0.48592     0.005159  0.467191
# 7                              raw  0.45296     0.004801  0.434516

# %%
if retr_slice is not None:
    print("Retrieval Slice:")
    display(retr_slice.sort_values(["slice_name", "Recall@K"], ascending=[True, False]))

if rank_slice is not None:
    print("Ranking Slice:")
    display(rank_slice.sort_values(["slice_name", "NDCG@K"], ascending=[True, False]))
# Out:
# Retrieval Slice:
#                slice_name                           method     Hit@K  \
# 0    slice_a_multi_target                 popularity_train  0.892414
# 1    slice_a_multi_target  rag_chunk_v1_vector_blend_query  0.823448
# 2    slice_a_multi_target     rag_chunk_v1_query_plus_desc  0.798621
# 3    slice_a_multi_target                 multi_mean_train  0.794483
# 4    slice_a_multi_target       fusion_c_raw_plus_behavior  0.777931
# 5    slice_a_multi_target                     two_tower_v1  0.773793
# 6    slice_a_multi_target           rag_chunk_v1_raw_query  0.737931
# 7    slice_a_multi_target                              raw  0.747586
# 8   slice_b_single_target                 popularity_train  0.754820
# 9   slice_b_single_target  rag_chunk_v1_vector_blend_query  0.513715
# 10  slice_b_single_target     rag_chunk_v1_query_plus_desc  0.497665
# 11  slice_b_single_target                     two_tower_v1  0.496136
# 12  slice_b_single_target       fusion_c_raw_plus_behavior  0.489597
# 13  slice_b_single_target           rag_chunk_v1_raw_query  0.470573
# 14  slice_b_single_target                 multi_mean_train  0.466921
# 15  slice_b_single_target                              raw  0.434820
#
#     Precision@K  Recall@K
# 0      0.018110  0.647212
# 1      0.014262  0.516522
# 2      0.013559  0.484910
# 3      0.013117  0.471565
# 4      0.012924  0.461392
# 5      0.012772  0.460228
# 6      0.012234  0.440120
# 7      0.012152  0.429578
# 8      0.007548  0.754820
# 9      0.005137  0.513715
# 10     0.004977  0.497665
# 11     0.004961  0.496136
# 12     0.004896  0.489597
# 13     0.004706  0.470573
# 14     0.004669  0.466921
# 15     0.004348  0.434820
# Ranking Slice:
#                slice_name                                             method  \
# 0    slice_a_multi_target          two_tower_v1_v2a_embed_query_logpop_blend
# 1    slice_a_multi_target                two_tower_v1_heuristic_logpop_blend
# 2    slice_a_multi_target  rag_chunk_v1_vector_blend_query_v2a_embed_quer...
# 3    slice_a_multi_target                    rag_chunk_v1_vector_blend_query
# 4    slice_a_multi_target                       rag_chunk_v1_query_plus_desc
# 5    slice_a_multi_target                         fusion_c_raw_plus_behavior
# 6    slice_a_multi_target                                   multi_mean_train
# 7    slice_a_multi_target                                                raw
# 8    slice_a_multi_target                             rag_chunk_v1_raw_query
# 9    slice_a_multi_target                                   popularity_train
# 10   slice_a_multi_target                                       two_tower_v1
# 11  slice_b_single_target          two_tower_v1_v2a_embed_query_logpop_blend
# 12  slice_b_single_target                two_tower_v1_heuristic_logpop_blend
# 13  slice_b_single_target  rag_chunk_v1_vector_blend_query_v2a_embed_quer...
# 14  slice_b_single_target                                   popularity_train
# 15  slice_b_single_target                    rag_chunk_v1_vector_blend_query
# 16  slice_b_single_target                       rag_chunk_v1_query_plus_desc
# 17  slice_b_single_target                         fusion_c_raw_plus_behavior
# 18  slice_b_single_target                                   multi_mean_train
# 19  slice_b_single_target                             rag_chunk_v1_raw_query
# 20  slice_b_single_target                                                raw
# 21  slice_b_single_target                                       two_tower_v1
#
#        Hit@K  Precision@K  Recall@K     MAP@K    NDCG@K       MRR  \
# 0   0.281379     0.032138  0.117319  0.035030  0.070334  0.082787
# 1   0.271724     0.031172  0.113367  0.034181  0.068322  0.081396
# 2   0.231724     0.026483  0.098068  0.031696  0.060467  0.073175
# 3   0.191724     0.020552  0.078537  0.028929  0.052658  0.070813
# 4   0.184828     0.020000  0.075068  0.027721  0.050566  0.067662
# 5   0.172414     0.019034  0.070175  0.025696  0.046757  0.061264
# 6   0.188966     0.019724  0.071700  0.021733  0.044159  0.056376
# 7   0.143448     0.015172  0.055964  0.021677  0.038812  0.053255
# 8   0.146207     0.015862  0.061290  0.019391  0.037628  0.046195
# 9   0.128276     0.014069  0.053728  0.019418  0.035444  0.047469
# 10  0.091034     0.009931  0.038280  0.009408  0.020537  0.021192
# 11  0.190573     0.019057  0.190573  0.068753  0.096885  0.068753
# 12  0.188450     0.018845  0.188450  0.066176  0.094404  0.066176
# 13  0.178344     0.017834  0.178344  0.063985  0.090412  0.063985
# 14  0.152527     0.015253  0.152527  0.052514  0.075428  0.052514
# 15  0.096476     0.009648  0.096476  0.036319  0.050162  0.036319
# 16  0.096391     0.009639  0.096391  0.035141  0.049263  0.035141
# 17  0.080000     0.008000  0.080000  0.025888  0.038348  0.025888
# 18  0.076773     0.007677  0.076773  0.025572  0.037302  0.025572
# 19  0.072272     0.007227  0.072272  0.025462  0.036221  0.025462
# 20  0.067261     0.006726  0.067261  0.025117  0.034786  0.025117
# 21  0.044076     0.004408  0.044076  0.010381  0.018015  0.010381
#
#     OracleHit@K  OracleNDCG@K    ILD@10  CatalogCoverage@10  Novelty@10  \
# 0      0.773793      0.533618  0.201265            0.434921    6.534829
# 1      0.773793      0.533618  0.203806            0.412698    6.504750
# 2      0.823448      0.589142  0.207860            0.349206    6.234571
# 3      0.823448      0.589142  0.175855            0.946032    9.096803
# 4      0.798621      0.558915  0.171459            0.952381    9.351036
# 5      0.777931      0.535239  0.122921            0.892063    9.840357
# 6      0.794483      0.546735  0.137577            0.955556    9.940777
# 7      0.747586      0.503441  0.161907            0.996825    9.955937
# 8      0.737931      0.509606  0.176664            0.984127    9.517988
# 9      0.892414      0.707962  0.212240            0.034921    5.312688
# 10     0.773793      0.533618  0.256915            0.933333   12.163190
# 11     0.496136      0.496136  0.202881            0.504762    6.281407
# 12     0.496136      0.496136  0.204683            0.501587    6.257840
# 13     0.513715      0.513715  0.208409            0.444444    6.189598
# 14     0.754820      0.754820  0.212341            0.034921    5.317765
# 15     0.513715      0.513715  0.171497            1.000000    9.078711
# 16     0.497665      0.497665  0.168787            1.000000    9.303286
# 17     0.489597      0.489597  0.135645            1.000000    9.641518
# 18     0.466921      0.466921  0.147290            1.000000    9.790245
# 19     0.470573      0.470573  0.174481            1.000000    9.405513
# 20     0.434820      0.434820  0.160650            1.000000    9.830787
# 21     0.496136      0.496136  0.261930            0.987302   12.167824
#
#     PersonalizationGapVsPopularity@10                 retrieval_method
# 0                            0.798229                     two_tower_v1
# 1                            0.793487                     two_tower_v1
# 2                            0.800892  rag_chunk_v1_vector_blend_query
# 3                            0.986180  rag_chunk_v1_vector_blend_query
# 4                            0.987796     rag_chunk_v1_query_plus_desc
# 5                            0.986083       fusion_c_raw_plus_behavior
# 6                            0.982319                 multi_mean_train
# 7                            0.983968                              raw
# 8                            0.987783           rag_chunk_v1_raw_query
# 9                            0.000000                 popularity_train
# 10                           0.997354                     two_tower_v1
# 11                           0.721825                     two_tower_v1
# 12                           0.715579                     two_tower_v1
# 13                           0.781731  rag_chunk_v1_vector_blend_query
# 14                           0.000000                 popularity_train
# 15                           0.983263  rag_chunk_v1_vector_blend_query
# 16                           0.984746     rag_chunk_v1_query_plus_desc
# 17                           0.973742       fusion_c_raw_plus_behavior
# 18                           0.976504                 multi_mean_train
# 19                           0.985173           rag_chunk_v1_raw_query
# 20                           0.979193                              raw
# 21                           0.995516                     two_tower_v1

# %%
try:
    import matplotlib.pyplot as plt
except ImportError:
    plt = None

if plt is not None and rank_overall is not None and "NDCG@K" in rank_overall.columns:
    df = rank_overall.sort_values("NDCG@K", ascending=True)
    fig, ax = plt.subplots(figsize=(8, max(3, 0.4 * len(df))))
    ax.barh(df["method"], df["NDCG@K"])
    ax.set_xlabel("NDCG@K (ranking contract)")
    ax.set_title(f"Ranking overall — {EVAL_RUN}")
    plt.tight_layout()
    plt.show()
else:
    print("matplotlib not available or ranking table missing; tables above are enough.")
